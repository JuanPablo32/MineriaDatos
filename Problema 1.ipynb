# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
peso = array([68.78,74.11,71.73,69.88,67.25,68.78,68.34,67.01,63.45,71.19,67.19,65.80,64.30,67.97,72.18,65.27,66.09,67.51,70.10,68.25,67.89,68.14,69.08,72.80,67.42,68.49,68.61,74.03,71.52,69.18])
altura = array([162,212,220,206,152,183,167,175,156,186,183,163,163,172,194,168,161,164,188,187,162,192,184,206,175,154,187,212,195,205])

# %%
peso
# Out:
# array([68.78, 74.11, 71.73, 69.88, 67.25, 68.78, 68.34, 67.01, 63.45,
#        71.19, 67.19, 65.8 , 64.3 , 67.97, 72.18, 65.27, 66.09, 67.51,
#        70.1 , 68.25, 67.89, 68.14, 69.08, 72.8 , 67.42, 68.49, 68.61,
#        74.03, 71.52, 69.18])

# %%
altura
# Out:
# array([162, 212, 220, 206, 152, 183, 167, 175, 156, 186, 183, 163, 163,
#        172, 194, 168, 161, 164, 188, 187, 162, 192, 184, 206, 175, 154,
#        187, 212, 195, 205])

# %%
plt.scatter(altura,peso)

# %%
plt.plot(altura,peso,'o')
#otra forma de graficar
linex=array([150,220])
liney=array([64,74])
plt.plot(linex,liney)
